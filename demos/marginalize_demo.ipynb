# %%
import numpy as np

import ebm_utils
from ebm_utils.analysis.plot_utils import ebm_marginalize_feat
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.14.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
C = np.random.uniform(0, 1, size=(100, 5))
Y = C[:, 0]*2
feat_names = [str(x) for x in range(5)]

ebm_marginalize_feat(C, Y, '0', feat_names=feat_names, plot_every=1, classification=False)
ebm_marginalize_feat(C, Y, '1', feat_names=feat_names, plot_every=1, classification=False)
