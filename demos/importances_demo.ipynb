# %%
import numpy as np
from ebm_utils.analysis.plot_utils import plot_importances

from interpret.glassbox import ExplainableBoostingRegressor as ebr
from interpret import show
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.14.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
# Make data.
X = np.random.uniform(0, 1, size=(1000, 2))
Y = X[:, 0]*X[:, 1]

# Fit the model.
ebm = ebr(interactions=2)
ebm.fit(X, Y)

# Plot importances.
plot_importances(ebm, 3)
